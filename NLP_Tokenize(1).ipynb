# %%
from nltk.tokenize import WordPunctTokenizer as punctTok
from nltk.tokenize import WhitespaceTokenizer as spaceTok
from nltk.tokenize import TreebankWordTokenizer as tbwTok
from nltk.tokenize import TweetTokenizer as twtTok

# %%
Sentence = "you are going to Enjoy this Sunday, aren't you?"
punctTokens=punctTok().tokenize(Sentence)
print(punctTokens)
# Out:
# ['you', 'are', 'going', 'to', 'Enjoy', 'this', 'Sunday', ',', 'aren', "'", 't', 'you', '?']

# %%
spcTok = spaceTok().tokenize(Sentence)
print(spcTok)
# Out:
# ['you', 'are', 'going', 'to', 'Enjoy', 'this', 'Sunday,', "aren't", 'you?']

# %%
tbTok = tbwTok().tokenize(Sentence)
print(tbTok)
# Out:
# ['you', 'are', 'going', 'to', 'Enjoy', 'this', 'Sunday', ',', 'are', "n't", 'you', '?']

# %%
tweet= "@sammy and @co are going for --->vacation, contact: 7666851879, it will be waaay tooooo much <3 funnnn!!!"
twit = twtTok(preserve_case = True, reduce_len=True,strip_handles=True,match_phone_numbers=True).tokenize(tweet)
print(twit)
# Out:
# ['and', 'are', 'going', 'for', '--->', 'vacation', ',', 'contact', ':', '7666851879', ',', 'it', 'will', 'be', 'waaay', 'tooo', 'much', '<3', 'funnn', '!', '!', '!']

# %%
from nltk.tokenize import MWETokenizer
mweTok = MWETokenizer([('I','am'),('as','soon','as')])
mweTok.add_mwe(('you','should'))
strin ="I am an Engineer, as soon as you see defect you should report"
stk= mweTok.tokenize(strin.split())
print(stk)
# Out:
# ['I_am', 'an', 'Engineer,', 'as_soon_as', 'you', 'see', 'defect', 'you_should', 'report']

# %%
from nltk.stem import PorterStemmer
prt = PorterStemmer()
prtStem = prt.stem(("retrospective"),to_lowercase = True)
print(prtStem)
# Out:
# retrospect

# %%
from nltk.stem import SnowballStemmer

print(" ".join(SnowballStemmer.languages))

stemmer = SnowballStemmer("english")
print(stemmer.stem("availability"))
# Out:
# arabic danish dutch english finnish french german hungarian italian norwegian porter portuguese romanian russian spanish swedish
# avail

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()
print(wnl.lemmatize('radii'))
# Out:
# radius

# %%
import nltk
nltk.download('wordnet')
help(nltk.stem.WordNetLemmatizer)
# Out:
# Help on class WordNetLemmatizer in module nltk.stem.wordnet:
#
# class WordNetLemmatizer(builtins.object)
#  |  WordNet Lemmatizer
#  |
#  |  Lemmatize using WordNet's built-in morphy function.
#  |  Returns the input word unchanged if it cannot be found in WordNet.
#  |
#  |      >>> from nltk.stem import WordNetLemmatizer
#  |      >>> wnl = WordNetLemmatizer()
#  |      >>> print(wnl.lemmatize('dogs'))
#  |      dog
#  |      >>> print(wnl.lemmatize('churches'))
#  |      church
#  |      >>> print(wnl.lemmatize('aardwolves'))
#  |      aardwolf
#  |      >>> print(wnl.lemmatize('abaci'))
#  |      abacus
#  |      >>> print(wnl.lemmatize('hardrock'))
#  |      hardrock
#  |
#  |  Methods defined here:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  lemmatize(self, word: str, pos: str = 'n') -> str
#  |      Lemmatize `word` using WordNet's built-in morphy function.
#  |      Returns the input word unchanged if it cannot be found in WordNet.
#  |
#  |      :param word: The input word to lemmatize.
#  |      :type word: str
#  |      :param pos: The Part Of Speech tag. Valid options are `"n"` for nouns,
#  |          `"v"` for verbs, `"a"` for adjectives, `"r"` for adverbs and `"s"`
#  |          for satellite adjectives.
#  |      :param pos: str
#  |      :return: The lemma of `word`, for the given `pos`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True
